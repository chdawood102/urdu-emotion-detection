# %%
import subprocess

packages = [
    "transformers",
    "torch",
    "datasets",
    "pandas",
    "scikit-learn",
    "matplotlib",
    "seaborn",
    "gradio"
]
for package in packages : 
    print(f"installing {package}...")
    subprocess.run(["pip","install",package])
    print(f"{package} done")
print("\nAll libraries installed!")
# Out:
# installing transformers...
# transformers done
# installing torch...
# torch done
# installing datasets...
# datasets done
# installing pandas...
# pandas done
# installing scikit-learn...
# scikit-learn done
# installing matplotlib...
# matplotlib done
# installing seaborn...
# seaborn done
# installing gradio...
# gradio done
#
# All libraries installed!

# %%
import transformers
import torch
import pandas as pd
import sklearn
import matplotlib
import seaborn
import gradio

print("transformers:", transformers.__version__)
print("torch:", torch.__version__)
print("pandas:", pd.__version__)
print("sklearn:", sklearn.__version__)
print("\n Everything is working perfectly!")
# Out:
# transformers: 5.7.0
# torch: 2.11.0+cpu
# pandas: 3.0.2
# sklearn: 1.8.0
#
#  Everything is working perfectly!

# %%
import pandas as pd

data = {
    "text": [
        # Happy
        "میں بہت خوش ہوں",
        "آج کا دن بہت اچھا تھا",
        "مجھے بہت خوشی ہوئی",
        "یہ خبر سن کر دل خوش ہوگیا",
        "آج بہت مزہ آیا",
        # Angry
        "مجھے بہت غصہ آ رہا ہے",
        "یہ بالکل غلط ہے",
        "یہ سن کر بہت غصہ آیا",
        "اتنی بے انصافی کیوں",
        # Fear
        "مجھے ڈر لگ رہا ہے",
        "یہ سوچ کر ڈر لگتا ہے",
        "آگے کیا ہوگا سوچ کر ڈر لگتا ہے",
        # Sad
        "مجھے بہت دکھ ہوا",
        "یہ بہت برا ہوا",
        "دل بہت اداس ہے",
        "آنکھوں میں آنسو آ گئے",
        # Neutral
        "سب کچھ ٹھیک ہے",
        "کوئی خاص بات نہیں",
        "آج معمول کا دن تھا",
        "کام ہو گیا"
    ],
    "emotion": [
        "happy", "happy", "happy", "happy", "happy",
        "angry", "angry", "angry", "angry",
        "fear", "fear", "fear",
        "sad", "sad", "sad", "sad",
        "neutral", "neutral", "neutral", "neutral"
    ]
}

df = pd.DataFrame(data)
df.to_csv("urdu_emotions.csv", index=False)

print(" Dataset created and saved!")
print(f"Total rows: {len(df)}")
print("\nSample:")
print(df.head(10))
# Out:
#  Dataset created and saved!
# Total rows: 20
#
# Sample:
#                         text emotion
# 0            میں بہت خوش ہوں   happy
# 1      آج کا دن بہت اچھا تھا   happy
# 2         مجھے بہت خوشی ہوئی   happy
# 3  یہ خبر سن کر دل خوش ہوگیا   happy
# 4             آج بہت مزہ آیا   happy
# 5      مجھے بہت غصہ آ رہا ہے   angry
# 6            یہ بالکل غلط ہے   angry
# 7       یہ سن کر بہت غصہ آیا   angry
# 8        اتنی بے انصافی کیوں   angry
# 9          مجھے ڈر لگ رہا ہے    fear
